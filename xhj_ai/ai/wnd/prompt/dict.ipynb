# %%
name = ['周杰伦'，'陈奕迅','周星驰']
score = [95,99,100]
# Out:
#   Cell In[5], line 1
#     name = ['周杰伦'，'陈奕迅','周星驰']
#                  ^
# SyntaxError: invalid character '，' (U+FF0C)

# %%
# dict
d = {'Michale':95,'Bob':75,'Tracy':85}
d['Michale']
# 从第一个字找到最后一个字
# 形象理解为书本的最前面的索引部分
# Hash？根据key 进行哈希计算 结果是唯一值 存放的是值的地址
# key是没有顺序的
# Out:
# 95

# %%
d['Adam'] = 67
d['Adam']
d['jack'] = 88
d['jack']
# Out:
# 88

# %%
# 初始化设计 key:value,动态的添加
# 代码一复杂， dict 就不好掌握了
# 如何让代码更健壮呢？
# d['Thomas']
# dict in
"Thomas" in d  # False
print(d.get('Thomas'))  # None
print(d.get('Thomas',-1))
# Out:
# None
# -1

# %%
# d.pop('Bob')
# d

key = [1,2,3]
d[key] = 'a list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 # d.pop('Bob')
#       2 # d
#       4 key = [1,2,3]
# ----> 5 d[key] = 'a list'
#
# TypeError: unhashable type: 'list'

# %%
# { }申明了Set，存储的key，没有value
s = { 1, 2, 3 }
s
# Out:
# {1, 2, 3}

# %%
s = set([1,2,3,2,5])
s
s.add(4)
s
s.remove(4)
# Out:
# {1, 2, 3, 5}

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}
s1 & s2  #交集
s1 | s2  #并集
# Out:
# {1, 2, 3, 4}

# %%
a = ['c','b','a']
a.sort()  # 可变对象（会改变原来的对象），指向的还是原来的内存地址
a
# Out:
# ['a', 'b', 'c']

# %%
str = 'abc' 
#字符串对象 String replace
print(str.replace('a','A'))
print(str)
# Out:
# Abc
# abc
